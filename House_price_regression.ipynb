# %%
# Install TensorFlow using Colab's tensorflow_version command
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

# %%
# Import libraries
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
# Check TensorFlow version
print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.2.0

# %% [markdown]
# ## Problem Statement
#
# Using example data, develop a model that predicts house prices based on the size of a house.

# %% [markdown]
# ## Get Data

# %%
# You need to upload the file, AmesHousing-05-2001.csv provided with this course
from google.colab import files

# only load the single file
uploaded = files.upload()
# csv_housefile contains the name of the first, and only file uploaded
csv_housefile = next(iter(uploaded.keys()))

print('User uploaded file "{name}" with length {length} bytes'.format(
      name=csv_housefile, length=len(uploaded[csv_housefile])))
# Out:
#      <input type="file" id="files-845bfeeb-f1c9-4df9-b85c-dbe88437ea45" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-845bfeeb-f1c9-4df9-b85c-dbe88437ea45">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving AmesHousing-05-2010.csv to AmesHousing-05-2010.csv
# User uploaded file "AmesHousing-05-2010.csv" with length 20140 bytes

# %% [markdown]
# ### Load the data into a pandas dataframe

# %%
import pandas as pd

# load the housing data into a pandas dataframe for easy viewing and manipulation
df_housing = pd.read_csv(csv_housefile)
df_housing.head(5)
# Out:
#    Order        PID  MS SubClass  ... Sale Type  Sale Condition  SalePrice
# 0      1  526301100           20  ...       WD           Normal     215000
# 1     13  527166040           60  ...       WD           Normal     180400
# 2     38  528112020           20  ...       WD           Normal     306000
# 3     56  528240070           60  ...       WD           Normal     216500
# 4     59  528292020           60  ...       WD           Normal     222500
#
# [5 rows x 82 columns]

# %% [markdown]
# ### Visualize the House Price data
#
# We use panda's  head method to look at the first few rows of data.  This will give us an understanding of the data we are working with.

# %%
# Visualize the dataset
 
# turn on option to display all columns, otherwise some columns may be hidden
pd.set_option('display.max_columns', None)  
# print the column names and first 5 rows of data
df_housing = df_housing.dropna(subset=['Total Bsmt SF', 'Gr Liv Area'])
df_housing.head(5)
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0   NaN       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 1   NaN       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 2   NaN       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 3   NaN       Reg          Lvl    AllPub     Corner        Gtl        NAmes
# 4   NaN       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 0        Norm        Norm      1Fam      1Story             6             5
# 1       Feedr        Norm      1Fam      1Story             5             6
# 2        Norm        Norm      1Fam      1Story             6             6
# 3        Norm        Norm      1Fam      1Story             7             5
# 4        Norm        Norm      1Fam      2Story             5             5
#
#    Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st Exterior 2nd  \
# 0        1960            1960        Hip   CompShg      BrkFace      Plywood
# 1        1961            1961      Gable   CompShg      VinylSd      VinylSd
# 2        1958            1958        Hip   CompShg      Wd Sdng      Wd Sdng
# 3        1968            1968        Hip   CompShg      BrkFace      BrkFace
# 4        1997            1998      Gable   CompShg      VinylSd      VinylSd
#
#   Mas Vnr Type  Mas Vnr Area Exter Qual Exter Cond Foundation Bsmt Qual  \
# 0        Stone         112.0         TA         TA     CBlock        TA
# 1         None           0.0         TA         TA     CBlock        TA
# 2      BrkFace         108.0         TA         TA     CBlock        TA
# 3         None           0.0         Gd         TA     CBlock        TA
# 4         None           0.0         TA         TA      PConc        Gd
#
#   Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1 BsmtFin Type 2  \
# 0        Gd            Gd            BLQ         639.0            Unf
# 1        TA            No            Rec         468.0            LwQ
# 2        TA            No            ALQ         923.0            Unf
# 3        TA            No            ALQ        1065.0            Unf
# 4        TA            No            GLQ         791.0            Unf
#
#    BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF Heating Heating QC Central Air  \
# 0           0.0        441.0         1080.0    GasA         Fa           Y
# 1         144.0        270.0          882.0    GasA         TA           Y
# 2           0.0        406.0         1329.0    GasA         TA           Y
# 3           0.0       1045.0         2110.0    GasA         Ex           Y
# 4           0.0        137.0          928.0    GasA         Gd           Y
#
#   Electrical  1st Flr SF  2nd Flr SF  Low Qual Fin SF  Gr Liv Area  \
# 0      SBrkr        1656           0                0         1656
# 1      SBrkr         896           0                0          896
# 2      SBrkr        1329           0                0         1329
# 3      SBrkr        2110           0                0         2110
# 4      SBrkr         928         701                0         1629
#
#    Bsmt Full Bath  Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  \
# 0             1.0             0.0          1          0              3
# 1             0.0             0.0          1          0              2
# 2             0.0             0.0          1          1              3
# 3             1.0             0.0          2          1              3
# 4             0.0             0.0          2          1              3
#
#    Kitchen AbvGr Kitchen Qual  TotRms AbvGrd Functional  Fireplaces  \
# 0              1           TA              7        Typ           2
# 1              1           TA              5        Typ           0
# 2              1           Gd              6        Typ           0
# 3              1           Ex              8        Typ           2
# 4              1           TA              6        Typ           1
#
#   Fireplace Qu Garage Type  Garage Yr Blt Garage Finish  Garage Cars  \
# 0           Gd      Attchd         1960.0           Fin          2.0
# 1          NaN      Attchd         1961.0           Unf          1.0
# 2          NaN      Attchd         1958.0           Unf          1.0
# 3           TA      Attchd         1968.0           Fin          2.0
# 4           TA      Attchd         1997.0           Fin          2.0
#
#    Garage Area Garage Qual Garage Cond Paved Drive  Wood Deck SF  \
# 0        528.0          TA          TA           P           210
# 1        730.0          TA          TA           Y           140
# 2        312.0          TA          TA           Y           393
# 3        522.0          TA          TA           Y             0
# 4        482.0          TA          TA           Y           212
#
#    Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  Pool Area Pool QC  \
# 0             62               0           0             0          0     NaN
# 1              0               0           0           120          0     NaN
# 2             36               0           0             0          0     NaN
# 3              0               0           0             0          0     NaN
# 4             34               0           0             0          0     NaN
#
#    Fence Misc Feature  Misc Val  Mo Sold  Yr Sold Sale Type Sale Condition  \
# 0    NaN          NaN         0        5     2010       WD          Normal
# 1  MnPrv          NaN         0        6     2010       WD          Normal
# 2    NaN         Gar2     12500        6     2010       WD          Normal
# 3    NaN          NaN         0        4     2010       WD          Normal
# 4  MnPrv          NaN         0        3     2010       WD          Normal
#
#    SalePrice
# 0     215000
# 1     105000
# 2     172000
# 3     244000
# 4     189900

# %% [markdown]
# L
#
#
# >  Total Bsmt SF = BsmtFin SF 1 +  BsmtFin SF 2 + Bsmt Unf SF
#
# > Gr Liv Area =  1st Flr SF +  2nd Flr SF
#
# But, there is no feature for the total space in the house which is the sum of Basement and Upper floors or (Total Bsmt SF + Gr Liv Area ).  So let's add a new feature column containing this value called 'Total SF' to the dataset.

# %%
 df_housing[['Total Bsmt SF', 'Gr Liv Area']].isnull().values.any()
# Out:
# False

# %% [markdown]
# No missing values, so no additional work is required.  So we can add the new column Total SF.

# %%
# Add new feature column Total SF = Total Bsmt SF + Gr Liv Area
df_housing['Total SF'] = df_housing['Total Bsmt SF'] + df_housing['Gr Liv Area']

# %% [markdown]
# And we can check that the numbers add and see associated sale price

# %%
# see the basement and living area, total sf, and price columns
print(df_housing[['Total Bsmt SF', 'Gr Liv Area', 'Total SF', 'SalePrice']].head(5) )

df_housing[['Total Bsmt SF', 'Gr Liv Area', 'Total SF', 'SalePrice']].head(5).isnull().values.any()
# Out:
#    Total Bsmt SF  Gr Liv Area  Total SF  SalePrice
# 0         1080.0         1656    2736.0     215000
# 1          882.0          896    1778.0     105000
# 2         1329.0         1329    2658.0     172000
# 3         2110.0         2110    4220.0     244000
# 4          928.0         1629    2557.0     189900
# False

# %% [markdown]
# ### Visualize the data.
#
# We visualize the data to give us some idea of the relationships between the various features.  To do that we create a  function to plot the data.

# %%
# This function visualizes our data and optionally a learned line
def visualize_data(x_vals, y_vals,
                   addn_x_vals=None, addn_y_vals=None, add_addn_reg_line=False):
  
  f, ax = plt.subplots(figsize=(8,8))
  plt.plot(x_vals, y_vals, 'ro')   # red dot for each data point
  # Optionally plot another set of data points in a different color and symbol
  if (addn_x_vals is not None):
    plt.plot(addn_x_vals, addn_y_vals, 'g^') # green triangles for additional data points
    # Optionally, plot a regression line.
    if (add_addn_reg_line):
      x_min_index = addn_x_vals.argmin()
      x_max_index = addn_x_vals.argmax()
      print(x_min_index,[addn_x_vals[x_min_index],addn_y_vals[x_min_index]] ) 
      print(x_max_index,[addn_x_vals[x_max_index],addn_y_vals[x_max_index]] ) 
      plt.plot([addn_x_vals[x_min_index],addn_y_vals[x_min_index]], 
               [addn_x_vals[x_max_index],addn_y_vals[x_max_index]], 
               'b-')  # draw a blue regression line
    
  plt.tick_params(axis='both', which='major', labelsize=14)
  
  plt.show()  # now plot the line showing the data and the optional line

# %% [markdown]
# ### Visualizing Total SF and Price
#
# Using the visualize_data function we can see the relationship between Total Square Feet (Total SF) and Price.

# %%
# Plot Total SF vs. Price
visualize_data(df_housing['Total SF'], df_housing['SalePrice'])

# %% [markdown]
# ### What does the visualization tell us?
#
# There seems to be a **linear** relationship between the size of the house (as shown in Total SF) and Price.
#
# This suggests that we should perform Linear Regression. Where the relationship in the data is:
#  y = mx + b.
#  Or in our case, Price = m * Total SF + b
#
# With respect to defining the appropriate equation, we can see the difference between traditional programming and Machine Learning as:
#
# * In tradition programming **we define what the equation** is through structures such as conditional statements
#
# * In Machine Learning, our model **learns from the data** what the appropriate equation is.

# %% [markdown]
# ## Prepare Data
#
# If values are on very different scales it will be difficult for the model to determine the relationships between features.  With our data, Square Footage (SF) ranges from 800-4200, and Prices range from 80,000 to 400,0000.  This means there is a nearly 100 times difference in scale.  When we normalize we will reduce both qualtities to the same scale while preserving the differences between prices and sizes of homes.  This will help our model learn the relationship between price and size.

# %%
# Scale data so SF and Sale Price are on similar scales with values 
#  from 0.0 to 1.0

from sklearn.preprocessing import MinMaxScaler

sf_scaler = MinMaxScaler()
sf_scaled = sf_scaler.fit_transform(df_housing['Total SF'].values.reshape(-1,1).astype(np.float64))
    
price_scaler = MinMaxScaler()
price_scaled = price_scaler.fit_transform(df_housing['SalePrice'].values.reshape(-1,1).astype(np.float64))

# %% [markdown]
# ## Create Model

# %%
# Create model using the TensorFlow Keras library
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(units=1, activation='linear', input_shape=(1,),
                                kernel_initializer='random_uniform',
                                bias_initializer='zeros'))

# %% [markdown]
# ### Compile the model

# %%
# Compile model
optimizer = "sgd"
model.compile(loss='mean_squared_error', optimizer=optimizer )

# %% [markdown]
# ## Train the Model
#
# Once the model has been defined and compiled we can train the model.  We do this with training data.
#
# We want to split our prepared dataset into 2 datasets.  One dataset will be used for training, and the other dataset will used for testing.  **We never used testing data for training or training data for testing.**

# %%
# Split the dataset into training dataset - 70%, Testing dataset - 30%
# we do this using the sklearn train_test_split method
from sklearn.model_selection import train_test_split

sf_train_scaled, sf_test_scaled, price_train_scaled, price_test_scaled = train_test_split(sf_scaled, 
                                                    price_scaled, 
                                                    test_size=0.3, random_state=42)

# %%
# Train model using data
initial_epochs = 8
batch_size = 10
train_hist = model.fit(sf_train_scaled, price_train_scaled, 
                       epochs=initial_epochs, batch_size=batch_size, verbose=1)

# Is 8 epochs enough??? Maybe/Maybe not
# Out:
# Epoch 1/8
# 205/205 [==============================] - 0s 2ms/step - loss: 0.0159
# Epoch 2/8
# 205/205 [==============================] - 0s 2ms/step - loss: 0.0099
# Epoch 3/8
# 205/205 [==============================] - 0s 2ms/step - loss: 0.0097
# Epoch 4/8
# 205/205 [==============================] - 0s 2ms/step - loss: 0.0095
# Epoch 5/8
# 205/205 [==============================] - 0s 2ms/step - loss: 0.0093
# Epoch 6/8
# 205/205 [==============================] - 0s 2ms/step - loss: 0.0091
# Epoch 7/8
# 205/205 [==============================] - 0s 2ms/step - loss: 0.0089
# Epoch 8/8
# 205/205 [==============================] - 0s 2ms/step - loss: 0.0087

# %% [markdown]
# ### Visually Confirm Model Training
#
# Our model learned the best weight and bias for our training data that it could through the defined number of epochs.  Let's see if a line drawn with the learned weight and bias looks reasonable.

# %%
#  predict the price with our trained model
price_predicted_scaled =  model.predict(sf_train_scaled)
visualize_data(sf_scaler.inverse_transform(sf_train_scaled), price_scaler.inverse_transform(price_train_scaled),
               sf_scaler.inverse_transform(sf_train_scaled), price_scaler.inverse_transform(price_predicted_scaled),
               add_addn_reg_line=False)
               
# If line looks bad, what do we do?

# %% [markdown]
# ### Evaluate Training
#
#
# Our trained model does not looks too good !!!
#
# What can we do?
#
# Should we change model architecture?  Does linear look incorrect?
#
# > NO
#
#
# What does loss look like?

# %%
def plot_loss(hist):
  # plot the loss
  plt.title('Loss History')
  plt.plot(hist.history['loss'])
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.show()

print(type(train_hist))
plot_loss(train_hist)
# Out:
# <class 'tensorflow.python.keras.callbacks.History'>

# %% [markdown]
# > LOSS STILL LOOKS HIGH.  BUT IS DECREASING.
#
#
#
# Perhaps we have not converged to the lowest loss.  What can we do????
#
# Train with more data?
#
# > NO.  WE HAVE ALL THE DATA
#
# Train for more epochs and check loss to ensure values have converged?
#  > YES!!!

# %% [markdown]
# ### Training more epochs
#
# The model is partially trained but the results are not great.  Let's go back and train the model some more.
#
# The question is how much more?
#
# We want to ensure the model is converged to a range of loss values.   So what we will see in the training output is the loss value starts to stay in a specific range .   It may go up or down a little, but there should be a stable range.

# %%
# Train model using data.  This time, train for additional epochs
# Also capture the changes over time in the history variable, train_hist_addn so we 
#   can see if loss is converging
addn_epochs = 1200
train_hist_addn =model.fit(sf_train_scaled, price_train_scaled,  
                     epochs=addn_epochs, verbose=1)
# Out:
# Epoch 1/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0086
# Epoch 2/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0085
# Epoch 3/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0085
# Epoch 4/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0084
# Epoch 5/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0084
# Epoch 6/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0083
# Epoch 7/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0083
# Epoch 8/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0082
# Epoch 9/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0082
# Epoch 10/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0081
# Epoch 11/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0081
# Epoch 12/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0080
# Epoch 13/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0080
# Epoch 14/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0079
# Epoch 15/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0079
# Epoch 16/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0078
# Epoch 17/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0078
# Epoch 18/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0077
# Epoch 19/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0077
# Epoch 20/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0076
# Epoch 21/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0076
# Epoch 22/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0076
# Epoch 23/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0075
# Epoch 24/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0075
# Epoch 25/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0074
# Epoch 26/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0074
# Epoch 27/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0073
# Epoch 28/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0073
# Epoch 29/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0073
# Epoch 30/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0072
# Epoch 31/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0072
# Epoch 32/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0072
# Epoch 33/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0071
# Epoch 34/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0071
# Epoch 35/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0070
# Epoch 36/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0070
# Epoch 37/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0070
# Epoch 38/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0069
# Epoch 39/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0069
# Epoch 40/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0069
# Epoch 41/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0068
# Epoch 42/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0068
# Epoch 43/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0068
# Epoch 44/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0067
# Epoch 45/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0067
# Epoch 46/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0067
# Epoch 47/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0066
# Epoch 48/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0066
# Epoch 49/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0066
# Epoch 50/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0065
# Epoch 51/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0065
# Epoch 52/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0065
# Epoch 53/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0064
# Epoch 54/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0064
# Epoch 55/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0064
# Epoch 56/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 57/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 58/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 59/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 60/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 61/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 62/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 63/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 64/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 65/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 66/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 67/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 68/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 69/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 70/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 71/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0059
# Epoch 72/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0059
# Epoch 73/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0059
# Epoch 74/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0059
# Epoch 75/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0058
# Epoch 76/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0058
# Epoch 77/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0058
# Epoch 78/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0058
# Epoch 79/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0058
# Epoch 80/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0057
# Epoch 81/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0057
# Epoch 82/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0057
# Epoch 83/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0057
# Epoch 84/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0056
# Epoch 85/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0056
# Epoch 86/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0056
# Epoch 87/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0056
# Epoch 88/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0056
# Epoch 89/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0055
# Epoch 90/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0055
# Epoch 91/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0055
# Epoch 92/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0055
# Epoch 93/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0055
# Epoch 94/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0054
# Epoch 95/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0054
# Epoch 96/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0054
# Epoch 97/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0054
# Epoch 98/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0054
# Epoch 99/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0054
# Epoch 100/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0053
# Epoch 101/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0053
# Epoch 102/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0053
# Epoch 103/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0053
# Epoch 104/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0053
# Epoch 105/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0052
# Epoch 106/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0052
# Epoch 107/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0052
# Epoch 108/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0052
# Epoch 109/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0052
# Epoch 110/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0052
# Epoch 111/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0052
# Epoch 112/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0051
# Epoch 113/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0051
# Epoch 114/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0051
# Epoch 115/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0051
# Epoch 116/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0051
# Epoch 117/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0051
# Epoch 118/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0050
# Epoch 119/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0050
# Epoch 120/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0050
# Epoch 121/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0050
# Epoch 122/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0050
# Epoch 123/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0050
# Epoch 124/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0050
# Epoch 125/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0050
# Epoch 126/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0049
# Epoch 127/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0049
# Epoch 128/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0049
# Epoch 129/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0049
# Epoch 130/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0049
# Epoch 131/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0049
# Epoch 132/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0049
# Epoch 133/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0049
# Epoch 134/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0048
# Epoch 135/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0048
# Epoch 136/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0048
# Epoch 137/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0048
# Epoch 138/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0048
# Epoch 139/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0048
# Epoch 140/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0048
# Epoch 141/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0048
# Epoch 142/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0047
# Epoch 143/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0047
# Epoch 144/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0047
# Epoch 145/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0047
# Epoch 146/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0047
# Epoch 147/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0047
# Epoch 148/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0047
# Epoch 149/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0047
# Epoch 150/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0047
# Epoch 151/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0047
# Epoch 152/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0046
# Epoch 153/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0046
# Epoch 154/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0046
# Epoch 155/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0046
# Epoch 156/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0046
# Epoch 157/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0046
# Epoch 158/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0046
# Epoch 159/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0046
# Epoch 160/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0046
# Epoch 161/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0046
# Epoch 162/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0046
# Epoch 163/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0045
# Epoch 164/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0045
# Epoch 165/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0045
# Epoch 166/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0045
# Epoch 167/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0045
# Epoch 168/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0045
# Epoch 169/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0045
# Epoch 170/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0045
# Epoch 171/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0045
# Epoch 172/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0045
# Epoch 173/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0045
# Epoch 174/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0045
# Epoch 175/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0045
# Epoch 176/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0044
# Epoch 177/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0044
# Epoch 178/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0044
# Epoch 179/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0044
# Epoch 180/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0044
# Epoch 181/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0044
# Epoch 182/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0044
# Epoch 183/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0044
# Epoch 184/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0044
# Epoch 185/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0044
# Epoch 186/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0044
# Epoch 187/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0044
# Epoch 188/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0044
# Epoch 189/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0044
# Epoch 190/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0043
# Epoch 191/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0043
# Epoch 192/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0043
# Epoch 193/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0043
# Epoch 194/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0043
# Epoch 195/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0043
# Epoch 196/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0043
# Epoch 197/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0043
# Epoch 198/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0043
# Epoch 199/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0043
# Epoch 200/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0043
# Epoch 201/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0043
# Epoch 202/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0043
# Epoch 203/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0043
# Epoch 204/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0043
# Epoch 205/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0043
# Epoch 206/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0043
# Epoch 207/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0042
# Epoch 208/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0042
# Epoch 209/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0042
# Epoch 210/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0042
# Epoch 211/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0042
# Epoch 212/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0042
# Epoch 213/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0042
# Epoch 214/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0042
# Epoch 215/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0042
# Epoch 216/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0042
# Epoch 217/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0042
# Epoch 218/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0042
# Epoch 219/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0042
# Epoch 220/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0042
# Epoch 221/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0042
# Epoch 222/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0042
# Epoch 223/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0042
# Epoch 224/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0042
# Epoch 225/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0042
# Epoch 226/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0042
# Epoch 227/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0042
# Epoch 228/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0042
# Epoch 229/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 230/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 231/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 232/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0041
# Epoch 233/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 234/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 235/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 236/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 237/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 238/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 239/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 240/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 241/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 242/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 243/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 244/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 245/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 246/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 247/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 248/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 249/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 250/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0041
# Epoch 251/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0041
# Epoch 252/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 253/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 254/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 255/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 256/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 257/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 258/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0040
# Epoch 259/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 260/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 261/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 262/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 263/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 264/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 265/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 266/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 267/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 268/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 269/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 270/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 271/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0040
# Epoch 272/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 273/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 274/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 275/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 276/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 277/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 278/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0040
# Epoch 279/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 280/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 281/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 282/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 283/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 284/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 285/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 286/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 287/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 288/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 289/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 290/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 291/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 292/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 293/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 294/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 295/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 296/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 297/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0040
# Epoch 298/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 299/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 300/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 301/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 302/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 303/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 304/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 305/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 306/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 307/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 308/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 309/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 310/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 311/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 312/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 313/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 314/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 315/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 316/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 317/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0039
# Epoch 318/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 319/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 320/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 321/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 322/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 323/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 324/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 325/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 326/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 327/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 328/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 329/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 330/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 331/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 332/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 333/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 334/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 335/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 336/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 337/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0039
# Epoch 338/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 339/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 340/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 341/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 342/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 343/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 344/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 345/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 346/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 347/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 348/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 349/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 350/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0039
# Epoch 351/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 352/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 353/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 354/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 355/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 356/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 357/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 358/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 359/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 360/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 361/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 362/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 363/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0039
# Epoch 364/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 365/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 366/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 367/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 368/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 369/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 370/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 371/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 372/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 373/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 374/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 375/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 376/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 377/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 378/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 379/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 380/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 381/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 382/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 383/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 384/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 385/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0039
# Epoch 386/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 387/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 388/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 389/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 390/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 391/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 392/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 393/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 394/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 395/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 396/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 397/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 398/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 399/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 400/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 401/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 402/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0039
# Epoch 403/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 404/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 405/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 406/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 407/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 408/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 409/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 410/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 411/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 412/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 413/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 414/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 415/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 416/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 417/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 418/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 419/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 420/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 421/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 422/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 423/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 424/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 425/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 426/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 427/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 428/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 429/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 430/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 431/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 432/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 433/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 434/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 435/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 436/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 437/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 438/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 439/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 440/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 441/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 442/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 443/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 444/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 445/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 446/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 447/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 448/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 449/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 450/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 451/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 452/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 453/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 454/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 455/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 456/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 457/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 458/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 459/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 460/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 461/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 462/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 463/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 464/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 465/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 466/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 467/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 468/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 469/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 470/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 471/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 472/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 473/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 474/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 475/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 476/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 477/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 478/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 479/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 480/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 481/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 482/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 483/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 484/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 485/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 486/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 487/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 488/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 489/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 490/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 491/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 492/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 493/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 494/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 495/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 496/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 497/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 498/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 499/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 500/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 501/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 502/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 503/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 504/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 505/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 506/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 507/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 508/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 509/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 510/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 511/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 512/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 513/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 514/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 515/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 516/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 517/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 518/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 519/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 520/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 521/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 522/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 523/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 524/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 525/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 526/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 527/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 528/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 529/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 530/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 531/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 532/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 533/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 534/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 535/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 536/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 537/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 538/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 539/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 540/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 541/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 542/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 543/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 544/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 545/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 546/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 547/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 548/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 549/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 550/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 551/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 552/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 553/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 554/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 555/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 556/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 557/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 558/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 559/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 560/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 561/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 562/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 563/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 564/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 565/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 566/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 567/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 568/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 569/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 570/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 571/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 572/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 573/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 574/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 575/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 576/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 577/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 578/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 579/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 580/1200
# ...
# Epoch 1011/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1012/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1013/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1014/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1015/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 1016/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1017/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1018/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1019/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1020/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1021/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1022/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 1023/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1024/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1025/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1026/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1027/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1028/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1029/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1030/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1031/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1032/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1033/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1034/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1035/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 1036/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1037/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1038/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1039/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1040/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1041/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1042/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1043/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1044/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1045/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1046/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1047/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1048/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 1049/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1050/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1051/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1052/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1053/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1054/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1055/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 1056/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1057/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1058/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1059/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1060/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1061/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 1062/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1063/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1064/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1065/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1066/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1067/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1068/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 1069/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1070/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1071/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1072/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1073/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1074/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1075/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1076/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1077/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1078/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1079/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1080/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1081/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 1082/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1083/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1084/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1085/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1086/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1087/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1088/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1089/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1090/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1091/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1092/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1093/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1094/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 1095/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1096/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1097/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1098/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1099/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1100/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 1101/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1102/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1103/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1104/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1105/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1106/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1107/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 1108/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1109/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1110/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1111/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1112/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1113/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1114/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 1115/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1116/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1117/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1118/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1119/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1120/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 1121/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 1122/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1123/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1124/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1125/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1126/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1127/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1128/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1129/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1130/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1131/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1132/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1133/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1134/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1135/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1136/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1137/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1138/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1139/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 1140/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1141/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1142/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1143/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1144/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1145/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1146/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1147/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1148/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1149/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1150/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1151/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1152/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 1153/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1154/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1155/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1156/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1157/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1158/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1159/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1160/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1161/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1162/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1163/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1164/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1165/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1166/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1167/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1168/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1169/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1170/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1171/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1172/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1173/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1174/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1175/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1176/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1177/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1178/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1179/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1180/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1181/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1182/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1183/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1184/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1185/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1186/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1187/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1188/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1189/1200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 1190/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1191/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1192/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1193/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1194/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1195/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1196/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1197/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1198/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1199/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1200/1200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0038

# %% [markdown]
# Plot the loss history values to see if our model converged.
#
# Because a model can have a history of many  different metrics over time, there is a history object which has a keys dictionary of
# metrics whose values were stored on each epoch. By plotting the values for the 'loss' key we can answer:
#
#
# 1.   Did the loss converge?
# 2.   How many epochs were required for the loss to converge?

# %%
# add the addition epochs to the  training history
train_hist.history['loss'].extend(train_hist_addn.history['loss'])   
plot_loss(train_hist)

# %% [markdown]
# ### Visually Confirm Model after Additional Training
#
# As the  plot showed, the model's loss converged by 1000 epochs.  So the model should be trained to allow us to make accurate predictions.
#
# Let's again plot the predicted price for each size.  And see if a line drawn with the learned weight and bias looks reasonable.

# %%
# Visualize data and regression line for learned weights
price_predicted_scaled =  model.predict(sf_train_scaled)
visualize_data(sf_scaler.inverse_transform(sf_train_scaled), 
               price_scaler.inverse_transform(price_train_scaled),
               sf_scaler.inverse_transform(sf_train_scaled), 
               price_scaler.inverse_transform(price_predicted_scaled),
               add_addn_reg_line=False)

# %% [markdown]
# **Yes.  The predicted line looks good!!!**

# %% [markdown]
# ## Evaluate Trained Model
#
# Once we have the model trained, we want to test **with data not used to train the model!!!**
#
# The use of data not used in training to test the model is key.  If you use training data our testing results will be overly accurate and will not reflect *real-life* usage of the trained model to make predictions.

# %%
# Make a price prediction on data the model has never seen before, i.e. 
#    the Test data square footage
price_test_pred_scaled = model.predict(sf_test_scaled)

# calculate the mean squared error for the prediction, lower is better
from sklearn.metrics import mean_squared_error
print("prediction mean squared error:", 
          mean_squared_error(price_test_scaled, price_test_pred_scaled ))

# Visualize data
#    plus the test square footage and predicted price
print('\nGreen triangles are Test square footage with predicted Price')
visualize_data(sf_scaler.inverse_transform(sf_test_scaled),
               price_scaler.inverse_transform(price_test_scaled),
               sf_scaler.inverse_transform(sf_test_scaled), 
               price_scaler.inverse_transform(price_test_pred_scaled),
               add_addn_reg_line=False)
print('\nOur predicted values fit the data well!')
# Out:
# prediction mean squared error: 0.005693718433287795
#
# Green triangles are Test square footage with predicted Price
# Our predicted values fit the data well!

# %% [markdown]
# ## What we have learned
#
#
#
# *   In Machine Learning we often spend considerable effort getting data in a form that our models can learn from the data.
# * A single neuron model can learn the appropriate slope and offset for the data.
# *   Building this model was made easier by TensorFlow's implementation of the Keras library.
# *   But to learn from the data we need to pass the data through the model enough times to get the loss to converge.
# *   When we do that, the model learns the data's slope and offset more accurately.
# *  And when we apply these learned values, the predict prices from the test data's square footage are reasonable.
